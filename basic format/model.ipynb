# %% [markdown]
# # Model Understanding Template
# 이 노트북은 특정 detection 모델의 구조와 중간 흐름을 이해하기 위한 기본 포맷
#
# ## 목표
# - 모델 입력과 출력 구조 파악
# - backbone / neck / head / decoder 흐름 확인
# - attention, query, proposal, feature map 같은 중간 표현 시각화
# - 논문 설명과 코드 구조를 같이 읽기

# %% [markdown]
# ## 1. 모델 개요\n
# \n
# - 모델 이름: `MODEL_NAME`\n
# - 계열: `backbone`, `2-stage`, `1-stage`, `transformer`, `multimodal`\n
# - 핵심 아이디어: `...`\n

# %%
# Fill in the model name and imports for the target detector.\n
MODEL_NAME = "TODO"\n
\n
# Example placeholders:\n
# from transformers import AutoImageProcessor, AutoModelForObjectDetection\n
# import torch\n
# import matplotlib.pyplot as plt\n

# %% [markdown]
# ## 2. 입력과 전처리\n
# \n
# - 이미지 크기\n
# - normalization\n
# - padding / resizing\n
# - annotation format\n

# %% [markdown]
# ## 3. Backbone / Feature Flow\n
# \n
# - 어떤 feature map이 생성되는지\n
# - resolution이 어떻게 줄어드는지\n
# - multi-scale feature를 쓰는지\n

# %% [markdown]
# ## 4. 중간 표현 시각화\n
# \n
# - attention map\n
# - query / proposal\n
# - top-k predictions\n
# - 실패 케이스\n

# %% [markdown]
# ## 5. 정리\n
# \n
# - 이 모델이 잘하는 것\n
# - 이 모델의 한계\n
# - 다음 모델에서 개선되는 점\n
