# %% [markdown]
# # Inference Template
#
# 이 노트북은 모델의 추론과 결과 시각화를 위한 기본 포맷
#
# ## 목표
# - 체크포인트 또는 pretrained model 로드
# - 단일 이미지 inference
# - box / score / label 시각화
# - threshold 변경에 따른 결과 비교

# %% [markdown]
# ## 1. Setup\n
# \n
# - 필요한 라이브러리 import\n
# - 모델과 processor 로드\n
# - 샘플 이미지 준비\n

# %%
# Example placeholders for the target detector.\n
MODEL_NAME = "TODO"\n
\n
# from transformers import AutoImageProcessor, AutoModelForObjectDetection\n
# from PIL import Image\n
# import torch\n
# import matplotlib.pyplot as plt\n

# %% [markdown]
# ## 2. Single Image Inference\n
# \n
# - 이미지 입력\n
# - 모델 forward\n
# - post-processing\n

# %% [markdown]
# ## 3. Visualization\n
# \n
# - predicted boxes\n
# - confidence score\n
# - predicted label\n

# %% [markdown]
# ## 4. Observation\n
# \n
# - 어떤 클래스에서 잘 맞는지\n
# - 작은 객체나 겹치는 객체에서 어떤 문제가 생기는지\n
# - threshold를 바꾸면 무엇이 달라지는지\n
